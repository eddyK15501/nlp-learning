# %%
# %conda install gensim
# %conda install cython

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
## Pre-trained Word2Vec model with 300 dimensional vectors
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_apple = wv['apple']

# %%
vec_apple
# Out:
# array([-0.06445312, -0.16015625, -0.01208496,  0.13476562, -0.22949219,
#         0.16210938,  0.3046875 , -0.1796875 , -0.12109375,  0.25390625,
#        -0.01428223, -0.06396484, -0.08056641, -0.05688477, -0.19628906,
#         0.2890625 , -0.05151367,  0.14257812, -0.10498047, -0.04736328,
#        -0.34765625,  0.35742188,  0.265625  ,  0.00188446, -0.01586914,
#         0.00195312, -0.35546875,  0.22167969,  0.05761719,  0.15917969,
#         0.08691406, -0.0267334 , -0.04785156,  0.23925781, -0.05981445,
#         0.0378418 ,  0.17382812, -0.41796875,  0.2890625 ,  0.32617188,
#         0.02429199, -0.01647949, -0.06494141, -0.08886719,  0.07666016,
#        -0.15136719,  0.05249023, -0.04199219, -0.05419922,  0.00108337,
#        -0.20117188,  0.12304688,  0.09228516,  0.10449219, -0.00408936,
#        -0.04199219,  0.01409912, -0.02111816, -0.13476562, -0.24316406,
#         0.16015625, -0.06689453, -0.08984375, -0.07177734, -0.00595093,
# ...

# %%
vec_apple.shape
# Out:
# (300,)

# %%
wv['decentralized']
# Out:
# array([ 1.09863281e-01, -2.36816406e-02, -1.72119141e-02,  2.71484375e-01,
#        -1.64062500e-01,  1.27929688e-01, -1.30859375e-01, -2.73437500e-01,
#         8.10546875e-02, -6.64062500e-02, -1.08886719e-01, -7.66601562e-02,
#        -6.48498535e-04,  9.17968750e-02, -5.00488281e-02,  1.43554688e-01,
#        -2.34375000e-01,  1.08032227e-02, -2.75390625e-01,  2.00195312e-02,
#        -1.26953125e-01,  2.69531250e-01,  2.71484375e-01,  1.69921875e-01,
#         3.41796875e-02, -1.20605469e-01, -1.73339844e-02, -1.82617188e-01,
#         1.50390625e-01, -1.81640625e-01,  1.24023438e-01, -8.05664062e-02,
#        -1.31835938e-01,  1.55273438e-01, -4.73632812e-02, -1.56250000e-01,
#         1.51367188e-01, -2.75390625e-01,  1.25000000e-01,  1.01562500e-01,
#         5.63964844e-02,  2.46093750e-01, -3.34472656e-02,  2.77343750e-01,
#         1.06445312e-01, -2.67578125e-01, -3.96484375e-01,  1.45507812e-01,
# ...

# %%
wv.most_similar('decentralized')
# Out:
# [('centralized', 0.6938875913619995),
#  ('decentralizing', 0.6072376370429993),
#  ('Decentralized', 0.6003851890563965),
#  ('decentralization', 0.5753238797187805),
#  ('decentralize', 0.5624064803123474),
#  ('centralization', 0.5549511909484863),
#  ('balkanized', 0.5285364985466003),
#  ('Decentralizing', 0.5228310823440552),
#  ('centralizing', 0.518268883228302),
#  ('fragmented', 0.5125389695167542)]

# %%
## Most similar words to 'economy'
wv.most_similar('economy')
# Out:
# [('economic', 0.7219074368476868),
#  ('econ_omy', 0.6942843794822693),
#  ('economies', 0.6638296842575073),
#  ('theeconomy', 0.6517611742019653),
#  ('ecomony', 0.6481687426567078),
#  ('recession', 0.6335979104042053),
#  ('ecomomy', 0.6117811799049377),
#  ('econonmy', 0.6115710139274597),
#  ('recesssion', 0.5793707966804504),
#  ('GDP', 0.5781735181808472)]

# %%
## Check how similar words are in relation to one another
wv.similarity('progressive', 'conservative')
# Out:
# 0.50979644

# %%
vec = wv['king'] - wv['man'] + wv['woman']

# %%
vec
# Out:
# array([ 4.29687500e-02, -1.78222656e-01, -1.29089355e-01,  1.15234375e-01,
#         2.68554688e-03, -1.02294922e-01,  1.95800781e-01, -1.79504395e-01,
#         1.95312500e-02,  4.09919739e-01, -3.68164062e-01, -3.96484375e-01,
#        -1.56738281e-01,  1.46484375e-03, -9.30175781e-02, -1.16455078e-01,
#        -5.51757812e-02, -1.07574463e-01,  7.91015625e-02,  1.98974609e-01,
#         2.38525391e-01,  6.34002686e-02, -2.17285156e-02,  0.00000000e+00,
#         4.72412109e-02, -2.17773438e-01, -3.44726562e-01,  6.37207031e-02,
#         3.16406250e-01, -1.97631836e-01,  8.59375000e-02, -8.11767578e-02,
#        -3.71093750e-02,  3.15551758e-01, -3.41796875e-01, -4.68750000e-02,
#         9.76562500e-02,  8.39843750e-02, -9.71679688e-02,  5.17578125e-02,
#        -5.00488281e-02, -2.20947266e-01,  2.29492188e-01,  1.26403809e-01,
#         2.49023438e-01,  2.09960938e-02, -1.09863281e-01,  5.81054688e-02,
# ...

# %%
wv.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
